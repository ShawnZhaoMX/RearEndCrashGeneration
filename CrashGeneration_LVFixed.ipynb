# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import random
import copy

# %%
import torch

# %%
# from behavior_model import LVBehaviorModel, FVBehaviorModel
# from synthetic_model import LVTrajSynthetic, FVTrajSynthetic
from behavior_model import FVBehaviorModel
from synthetic_model import FVTrajSynthetic

# %%
file_path = 'Synthetic_crash_scenarios.csv'

# Read the CSV file into a DataFrame
df = pd.read_csv(file_path)

# %%
device = torch.device('cuda' if torch.cuda.is_available() else 'cpu')
device
